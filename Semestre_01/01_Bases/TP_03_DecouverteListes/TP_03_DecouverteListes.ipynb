# %% [markdown]
# <center>
#     <span style="font-size:xx-large;font-style: bold;">
#         TP 03 Découverte des listes
#     </span>
# </center>

# %% [markdown]
# <div class = "alert  alert-danger">
#     Ceci est votre notebook contenant les questions, les fonctions et les tests de vos fonctions.
#     <ul>
#         <li> Penser à sauvegarder régulièrement. </li>
#     </ul>
#
#
#
# Les cellules peuvent être exécutées via le menu <b>Run</b>, via l'icône Play ou avec un raccourci clavier :
#     <ul>
#         <li> <code>Shift+Entrée</code> pour exécuter la cellule et passer à la suivante ;</li>
#         <li> <code>Ctrl+Entrée</code> pour exécuter la cellule sans passer à la suivante ;</li>
#         <li> <code>Alt+Entrée</code> pour exécuter la cellule et créer une nouvelle cellule en dessous.</li>
#         <li> <b>Il faut obligatoire exécuter vos fonctions.</b></li>
#         <li> <b>Il faut obligatoire exécuter des tests (ou faire vos propres tests).</b></li>
#     </ul>
# </div>

# %%
# Exécutez cette cellule pour pouvoir faire les tests
import _TP_01_DecouvertePython as test
# Out:
# Traceback (most recent call last):
#   File "<input>", line 2, in <module>
# ModuleNotFoundError: No module named '_TP_01_DecouvertePython'

# %% [markdown]
# # Autour des listes

# %% [markdown]
# ## Création et manipulation de listes

# %% [markdown]
# Rappels :
# * Une liste est une structure de données contenant une série de valeurs. Les valeurs sont séparées par des virgules et encadrées par des crochets. Par exemple <tt>L = [1, 2, 3]</tt>.
# * Pour accéder au e élément d’une liste on procède ainsi <tt>L[i]</tt>. Attention l’indexation commence à <tt>0</tt>.
# * Pour accéder à la taille de liste on utilise <tt>len[L]</tt>.
# * Pour ajouter un élément à une liste, on utilise <tt>L.append(4)</tt>.

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>generer_liste_entiers_01(n: int) -> list</tt> renvoyant
# la liste des entiers compris entre <tt>0</tt> (inclus) et <tt>n</tt> (exclus). On utilisera une boucle <tt>for</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>generer_liste_entiers_02(n: int) -> list</tt> renvoyant
# la liste des entiers compris entre <tt>0</tt> (inclus) et <tt>n</tt> (exclus). On utilisera une boucle <tt>while</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>generer_liste_entiers_03(deb: int, fin:int) ->
# list</tt> renvoyant la liste des entiers compris entre <tt>deb</tt> (inclus) et <tt>fin</tt> (inclus). On utilisera une boucle <tt>for</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>generer_liste_entiers_04(deb: int, fin:int) ->
# list</tt> renvoyant la liste des entiers compris entre <tt>deb</tt> (inclus) et <tt>fin</tt> (inclus). On utilisera une boucle <tt>while</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>generer_liste_pairs(n:int) -> list</tt> renvoyant la liste
# des entiers pairs compris entre <tt>0</tt> (inclus) et <tt>n</tt> (exclus).
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>generer_liste_impairs(n:int) -> list</tt> renvoyant la liste
# des entiers impairs compris entre <tt>0</tt> (inclus) et <tt>n</tt> (exclus).
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>is_multiple(n:int, m:int) -> bool</tt> renvoyant <tt>True</tt> si <tt>n</tt>
# est multiple de <tt>m</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         En utilisant la fonction précédente, écrire une fonction de signature <tt>genere_liste_multiple(n:int,
# m:int) -> list</tt> renvoyant les <tt>n</tt> premiers multiples de <tt>m</tt>.
#     </span>
# </div>

# %% [markdown]
# ## Recherche dans une liste
# Nous allons rechercher si un nombre est dans une liste.
# Commençons par générer une liste de nombre alétoires.

# %%
import random as rd
def generer_alea(nb: int) -> list :
    """
    Génération d'une liste nb de nombres aléatoires compris entre 0 inclus et nb exclus.
    """
    res = []
    for i in range(nb):
        res.append(rd.randrange(0,nb))
    return res

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>recherche_nb_01(nb: int, L: list) -> bool</tt> qui renvoie
# <tt>True</tt> si <tt>nb</tt> est dans <tt>L</tt>, <tt>False</tt> sinon. On utilisera une boucle <tt>for</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>recherche_nb_02(nb: int, L: list) -> bool</tt> qui renvoie
# <tt>True</tt> si <tt>nb</tt> est dans <tt>L</tt>, <tt>False</tt> sinon. On utilisera une boucle <tt>while</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>recherche_nb_03(nb: int, L: list) -> bool</tt> qui renvoie
# <tt>True</tt> si <tt>nb</tt> est dans <tt>L</tt>, <tt>False</tt> sinon. On n’utilisera pas explicitement de boucles <tt>for</tt> ou <tt>while</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>recherche_first_index_nb_01(nb: int, L: list)
# -> int</tt> qui renvoie l’index de la première appartion du nombre nb dans la liste <tt>L</tt>. La fonction renverra <tt>-1</tt> si <tt>nb</tt> n’est pas dans la liste. On utilisera une boucle <tt>for</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>recherche_first_index_nb_02(nb: int, L: list)
# -> int</tt> qui renvoie l’index de la première appartion du nombre <tt>nb</tt> dans la liste <tt>L</tt>. La fonction renverra <tt>-1</tt> si <tt>nb</tt>
# n’est pas dans la liste. On utilisera une boucle <tt>while</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>recherche_last_index_nb_01(nb: int, L: list) ->
# int</tt> qui renvoie l’index de la dernière appartion du nombre <tt>nb</tt> dans la liste <tt>L</tt>. La fonction renverra <tt>-1</tt> si <tt>nb</tt> n’est pas dans la liste.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>recherche_index_nb_01(nb: int, L: list) -> list</tt>
# qui renvoie la liste des index du nombre <tt>nb</tt> dans la liste <tt>L</tt>. La fonction renverra une liste vide si <tt>nb</tt> n’est pas dans la liste.
#     </span>
# </div>

# %% [markdown]
# ## Recherche d'un caractère dans une chaîne

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>is_char_in_str_01(lettre: str, mot: str) -> int</tt>
# qui renvoie <tt>True</tt> si <tt>lettre</tt> est dans <tt>mot</tt>, <tt>False</tt> sinon. On utilisera une boucle <tt>for</tt> ou <tt>while</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>is_char_in_str_02(lettre: str, mot: str) -> int</tt> qui renvoie <tt>True</tt> si <tt>lettre</tt> est dans <tt>mot</tt>, <tt>False</tt> sinon. On n’utilisera ni boucle <tt>for</tt> ni <tt>while</tt> explicite.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>compte_lettre_01(lettre: str, mot: str) -> int</tt>
# qui renvoie le nombre d’occurrences de <tt>lettre</tt> dans le <tt>mot</tt>.
#     </span>
# </div>

# %% [markdown]
# Les instructions suivantes permettent de charger l’ensemble des mots du dictionnaire dans la variable dictionnaire.
# dictionnaire est une liste de mots. Chacune des lettres de l’alphabet sont stockées dans la variable alphabet.

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'
def load_fichier(file):
    fid = open(file,'r')
    mots = fid.readlines()
    fid.close()
    return mots
liste_mots = load_fichier('liste_francais.txt')
# Out:
# Traceback (most recent call last):
#   File "<input>", line 7, in <module>
#   File "<input>", line 3, in load_fichier
# FileNotFoundError: [Errno 2] No such file or directory: 'liste_francais.txt'

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Écrire une fonction de signature <tt>compte_lettre_02(lettre: str, mots: list) -> int</tt> qui renvoie le nombre d’occurrences de <tt>lettre</tt> dans une liste de mots <tt>mots</tt>.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Quelle consonne apparaît le plus souvent? Quelle consonne apparaît le moins souvent? Indiquer le nombre d’occurrences dans chacun des mots.
#     </span>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left:3px solid #3c763d; border-radius:2px;">
#     <span style="color: #000000">
#         Ecrire une fonction de signature <tt>mots_plus_long(mots: list) -> str</tt> qui renvoie le mot le plus long.
#     </span>
# </div>
